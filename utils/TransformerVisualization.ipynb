# %%
import os

import tensorflow as tf

from tensor2tensor import problems
from tensor2tensor.bin import t2t_decoder  # To register the hparams set
from tensor2tensor.utils import registry
from tensor2tensor.utils import trainer_lib
from tensor2tensor.utils import usr_dir

from visualization import attention, visualization

# %%
# %%javascript
# require.config({
#   paths: {
#       d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min'
#   }
# });

# %%
HOME_DIR = '/net/me/merkur3/pham/depatt'
# HOME_DIR = '/home/phamthuonghai/Workspace/wheelie'
usr_dir.import_usr_dir(os.path.join(HOME_DIR, 't2t-str'))

def get_viz_data(problem_name, model_name, hparams_set, input_sentence):
    def fake_name(p_name):
        if 'dep_parse' in p_name:
            p_name = p_name.split('_')
            return '_'.join(p_name[:1] + p_name[3:])
        else:
            return p_name
    CHECKPOINT = os.path.join(HOME_DIR, 'train_data', fake_name(problem_name), model_name + '-' + hparams_set)
    data_dir = os.path.join(HOME_DIR, 'data', problem_name)
    with tf.Graph().as_default() as graph:
        visualizer = visualization.AttentionVisualizer(hparams_set, model_name, data_dir, problem_name, beam_size=4)

        tf.Variable(0, dtype=tf.int64, trainable=False, name='global_step')

        with tf.train.MonitoredTrainingSession(checkpoint_dir=CHECKPOINT, save_summaries_secs=0) as sess:
            output_string, inp_text, out_text, att_mats = visualizer.get_vis_data_from_string(sess, input_sentence)

    return inp_text, out_text, att_mats
# Out:
# INFO:tensorflow:Importing user module t2t-str from path /net/me/merkur3/pham/depatt
# [2018-06-01 03:25:56,131] Importing user module t2t-str from path /net/me/merkur3/pham/depatt

# %%
the_sentence = "Vracel|vracet_:T|VpYS---XR-AA---|1|6|Pred se|se_^(zvr._zájmeno/částice)|P7-X4----------|2|1|AuxT za|za|RR--7----------|3|1|AuxP tebou|ty|PP-S7--2-------|4|3|Adv ,|,|Z:-------------|5|6|AuxX ale|ale|J^-------------|6|0|Coord jeho|jeho_^(přivlast.)|PSXXXZS3-------|7|8|Atr auto|auto|NNNS1-----A----|8|9|Sb píchlo|píchnout_:W|VpNS---XR-AA--1|9|6|Pred ,|,|Z:-------------|10|6|AuxX telefon|telefon|NNIS1-----A----|11|12|Sb přestal|přestat|VpYS---XR-AA---|12|6|Pred fungovat|fungovat_:T|Vf--------A----|13|12|Obj ...|...|Z:-------------|14|0|AuxK"

# %% [markdown]
# ## transformer-transformer_base

# %% [markdown]
# For transformer_base, run the following cell, then run the last cell

# %%
inp_text, out_text, att_mats = get_viz_data("translate_csen_czeng", "transformer", "transformer_base", the_sentence)
# Out:
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# [2018-06-01 03:26:07,567] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# [2018-06-01 03:26:07,569] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# [2018-06-01 03:26:07,570] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# [2018-06-01 03:26:07,571] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# [2018-06-01 03:26:07,572] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# [2018-06-01 03:26:07,573] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# [2018-06-01 03:26:07,579] Using variable initializer: uniform_unit_scaling
# WARNING:tensorflow:Missing feature pos - ignoring.
# [2018-06-01 03:26:07,615] Missing feature pos - ignoring.
# ...

# %% [markdown]
# ## transformer_dep_parse-transformer_dep_parse_l*

# %% [markdown]
# For transformer_dep_parse, change layer_id to the layer you'd like, run the following cell then the last cell

# %%
layer_id = "transformer_dep_parse_l4"
inp_text, out_text, att_mats = get_viz_data("translate_dep_parse_csen_czeng", "transformer_dep_parse", layer_id, the_sentence)
# Out:
# INFO:tensorflow:Unsetting shared_embedding_and_softmax_weights.
# [2018-06-01 03:32:03,749] Unsetting shared_embedding_and_softmax_weights.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# [2018-06-01 03:32:03,751] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# [2018-06-01 03:32:03,752] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.dropout to 0.0
# [2018-06-01 03:32:03,753] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# [2018-06-01 03:32:03,754] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# [2018-06-01 03:32:03,755] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# [2018-06-01 03:32:03,756] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# ...

# %%
attention.show(inp_text, out_text, *att_mats)
# Out:
#   <span style="user-select:none">
#     Layer: <select id="layer"></select>
#     Attention: <select id="att_type">
#       <option value="all">All</option>
#       <option value="inp_inp">Input - Input</option>
#       <option value="inp_out">Input - Output</option>
#       <option value="out_out">Output - Output</option>
#     </select>
#   </span>
#   <div id='vis'></div>
